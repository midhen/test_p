# %% [markdown]
# ### If Statements

# %% [markdown]
# The simplest sort of way of controlling execution is to decide whether or not.
# We execute the code *if* some condition holds, so the
# statement in Python (and many other languages ) that lets us do this is called
# the `if` statement.
#
# The simplest form of the if statement looks like this:

# %%
x = 0.5

if x > 0:
    print "Hey!"
    print "x is positive"
print "This isn't part of the block, and will always print."
# Out:
# Hey!
# x is positive
# This isn't part of the block, and will always print.

# %% [markdown]
# Unlike in Java or C there are no parentheses: where languages like C and Java use
# indentation as a matter of style and readability, Python uses indentation
# to group lines of code.  In the above example, the two lines of code:
#
#     print "Hey!"
#     print "x is positive"
#
# are called a *block* of Python code, and form the body of the if statement.
# You'll notice that the last character in the line before the block starts
# is a colon `:`
# We will see that all flow control statements in
# Python expect a colon at the end of the statement.
#
# The block ends when Python encounters a line of code which is indented at
# the original level:

# %% [markdown]
# You may notice that we indented 4 spaces.
# The Canopy Python code editor overrides the tab key to instead do indenting with spaces.
#
# Sometimes there may be a number of different possibilities, and you want to
# do a different thing in each possible case.  The if statement can have
# additional blocks associated with it via the `elif` and `else` clauses:

# %%
x = 0

if x > 0:
    print "x is positive"
elif x == 0:
    print "x is zero"
else:
    print "x is negative"
# Out:
# x is zero

# %% [markdown]
# You can have as many elif clauses as you want, but at most one else clause,
# and the else clause must always come last.  In addition, Python will only
# execute the *first* block of code that matches:

# %%
x = 1.5

if x > 1:
    print "x is greater than 1"
elif x >= 0:
    print "x is non-negative"
# Out:
# x is greater than 1

# %% [markdown]
# In this example, if x is greater than 1, Python will only print "x is
# greater than 1", even though x satisfies both the if and elif clauses.
# If you wanted both to print, you should use two if statements or even nested if statements:

# %%
if x >= 0:
    if x > 1:
        print "x is greater than 1"
    print "x is non-negative"
# Out:
# x is greater than 1
# x is non-negative

# %% [markdown]
# #### Test values

# %% [markdown]
# The other thing we need to consider are the *conditions* that can be used
# in if and elif clauses of if statements.  Unlike some languages, Python
# will accept any expression as a condition.  Usually you will use a logical
# expression, as described in previous lectures, but any
# other expression will be evaluated, and the tested for truth.
#
# Most Python values will test as `True`, but a handful test as `False`.  These
# are:
#
# * `False`,
# * zero,
# * `None`,
# * empty containers (lists, tuples, dicts and sets),
# * and occassional instances of custom classes.
#
# This means you can do things like:

# %%
mylist = [3, 1, 4, 1, 5, 9]

if mylist:
    print "The first element is:", mylist[0]
else:
    print "There is no first element."
# Out:
# The first element is: 3

# %% [markdown]
# Because the list was not empty, it prints out the first element.  But if we instead ran the same code with an empty list:

# %%
mylist = []

if mylist:
    print "The first element is:", mylist[0]
else:
    print "There is no first element."
# Out:
# There is no first element.

# %% [markdown]
# then it prints out that there is no first element instead.
#
# Sometimes it pays to be explicit about what it is you are testing for.
# The above example is safe and reasonably clear, but what we are really
# testing for is whether the length is greater than or equal to 1, so it
# could be more clearly (and perhaps safely) written as:

# %%
if len(mylist) >= 1:
    print "The first element is:", mylist[0]
else:
    print "There is no first element."
# Out:
# There is no first element.

# %% [markdown]
# This is particularly the case when you want to check whether a variable
# holds the special `None` value.  You should *always* test for `None` using:

# %%
if x is None:
    print "No value supplied"

# %% [markdown]
# rather than just "`x == None`" or `not x`, as these may behave unexpectedly
# for some values of x.

# %% [markdown]
# ### While Loops

# %% [markdown]
# While loops iterate until a condition is met

# %% [markdown]
# #### Breaking out of a loop

# %%
i=0
while True:
    if i<3:
        print i
    else:
        break
    i=i+1
# Out:
# 0
# 1
# 2

# %%
plays=set(['Hamlet','Mackbeth','King Lear'])
while plays:
    play=plays.pop()
    print 'Perform', play
# Out:
# Perform King Lear
# Perform Mackbeth
# Perform Hamlet

# %% [markdown]
# ### For Loops

# %% [markdown]
# For loops iterate until a condition is met

# %%
for item in range(3):
    print item
# Out:
# 0
# 1
# 2

# %%
#for a large range, xrange() is faster and more efficient
for item in xrange(3):
    print item
# Out:
# 0
# 1
# 2

# %%
plays=set(['Hamlet','Mackbeth','King Lear'])
for play in plays:
    print 'Perform', play
# Out:
# Perform King Lear
# Perform Mackbeth
# Perform Hamlet

# %%
# For loop should not try to modify the sequence it is looping over

# %%
total=0
for i in range(1000000):
    total+=i
print total
# Out:
# 499999500000

# %%
#Downside - it creates a temporary list with million elements in memory
# -> better xrange()

# %%
values=[11,12,13,100]
for x in values:
    if x<=10:
        print 'found',x
        break
else:
    print 'All values greater than 10'
# Out:
# All values greater than 10

# %% [markdown]
# ### List Comprehension

# %%
# Original code
values=[10,21,4,7,12]
squares=[]
for x in values:
    squares.append(x**2)
print squares
# Out:
# [100, 441, 16, 49, 144]

# %%
#List Comprehension
squares=[x**2 for x in values]
print squares
# Out:
# [100, 441, 16, 49, 144]

# %%
filtered_squares=[x**2 for x in values if x<=10]
print filtered_squares
# Out:
# [100, 16, 49]

# %% [markdown]
# In Python 2.7 there are equivalent expressions for dictionaries:

# %%
square_dict={x:x**2 for x in values if x<=10}
print square_dict
# Out:
# {10: 100, 4: 16, 7: 49}

# %% [markdown]
# ### Generator Expressions

# %% [markdown]
# One downside of list comprehensions is that they create the full list of
# values.  For example, you can sum the list of squares by using the built-in
# `sum()` function:

# %%
sum([x**2 for x in values if x<=10])
# Out:
# 165

# %% [markdown]
# In many of these situations you can use a
# generator expression, which behaves analagously to `xrange()` and produces just one
# value at a time.
#
# To get a generator expression you simply leave out the square brackets in most
# cases:

# %%
sum(x**2 for x in values if x<=10)
# Out:
# 165

# %% [markdown]
# ### Functions

# %%
from IPython.display import Image
Image(filename='C:\Users\midhen\python_fcn.png')

# %%
def add(x,y):
    """Add two values"""
    a=x+y
    return a

# %%
print add(2,3)
# Out:
# 5

# %%
print add([1,2,3],[4,5,6])
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# Variable number of arguments

# %%
def add(x,*args):
    total=x
    for arg in args:
        total+=arg
    return total

# %%
print add(1,2,3,4)
# Out:
# 10

# %% [markdown]
# Multiple return values

# %%
from math import atan2
def to_polar(x,y):
    r=(x**2+y**2)**0.5
    theta=atan2(y,x)
    return r,theta

# %%
r,theta=to_polar(3,4)
print r,theta
# Out:
# 5.0 0.927295218002

# %% [markdown]
# Argument expansion

# %%
def add(x,y):
    return x+y

# %%
z=(2,3)
add(*z)
# Out:
# 5

# %% [markdown]
# Keyword argument expansion

# %%
w={'x':3,'y':3}
add(**w)
# Out:
# 6

# %% [markdown]
# ### Modules

# %% [markdown]
# #### From shell

# %%
# python ex.py

# %% [markdown]
# #### From interpreter

# %% [markdown]
# load and execute the module

# %%
# import ex

# %% [markdown]
# get/set module variable

# %%
# print ex.pi
# ex.pi=3.1415

# %% [markdown]
# call a module function

# %%
# t=[2,3,4]
# ex.sum(t)

# %% [markdown]
# reload module

# %%
# reload(ex)

# %% [markdown]
# A Python file can be used as a script, or as a module, or both

# %% [markdown]
# #### import function

# %%
# import square

# %% [markdown]
# aliasing a name

# %%
# import square as sq

# %% [markdown]
# importing specific names to local namespace

# %%
# from square import add

# %% [markdown]
# importing everything

# %%
# from square import *

# %% [markdown]
# #### Packages

# %% [markdown]
# Often a library (package) will contain several modules.
#
# foo/
# `__init__.py`
# `bar.py (defines func)`
# `baz.py (defines zap)`
#
# * The directory foo must be in the python search path
# * The file `__init__.py` indicates that foo is a package. It may be empty.
# * In the simplest case:
#      package=directory
#      module=python file

# %% [markdown]
# #### Standard Modules

# %%
from IPython.display import Image
Image(filename='C:\Users\midhen\python_modules.png')

# %% [markdown]
# PYTHONPATH is an environment variable (or set of registry entries on Win) that lists the directories Python searches for modules

# %% [markdown]
# Third party modules - Canopy package manager

# %% [markdown]
# ### Try and Except

# %%
"""import math
while True:
    try:
        text=raw_input('> ')
        if text[0]=='q':
            break
        x=float(text)
        y=math.log10(x)
        print "log10({0})={1}".format(x,y)
    except ValueError as exc:
        if exc.message=="math domain error":
            print "The value must be greater than 0"
        else:
            print "Could not '%s' convert to a floating point number" % text
"""

# %%
# except (ValueError,ZeroDivisionError):

# %% [markdown]
# ### Finally Clause

# %% [markdown]
# The finally clause always executes.
# Use it for code that needs to 'clean up' a resource whether the code executes succesfully or not.

# %%
"""
import os
import tempfile

fileno,path=tempfile.mkstemp()
f=open(path,'w')

try:
    f.write('Hello world!')
finally:
    #ensure that the file is closed
    f.close()
    #ensure that the temporary file si deleted
    os.remove(path)
"""
